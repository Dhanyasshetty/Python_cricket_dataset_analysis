# %%
#import pandas
import pandas as pd

# %%
#import dataset-csv file
df=pd.read_csv('python data cleaning -cricket dataset1.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
#Rename multiple columns in a list
df=df.rename(columns={'Mat':'Matches','NO':'Not Outs','HS':'Highest Inns Score','Ave':'Batting Average','BF':'Balls Faced','SR':'Batting Strike Rate'})

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 0                 334            99.94       9800+                58.60   29
# ...

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 0                334            99.94       9800+                58.60   29
# 1                186            62.15        1287                91.76    4
# 2               269*            61.87        2667                55.68    5
# 3                274            60.97       1707+                54.48    7
# 4               270*            60.83        416+                56.00   10
#
#    50  0   4s  6s
# 0  13  7  626   6
# 1   7  1  141  23
# 2   4  2  186   5
# 3  11  1  246  11
# 4   5  2  104   1

# %%
#check null values
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not Outs               False
# Runs                   False
# Highest Inns Score     False
# Batting Average        False
# Balls Faced             True
# Batting Strike Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 15       CL Walcott (WI)  1948-1960       44    74         7  3798
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 8                 207            58.61         NaN                  NaN   15
# 15                220            56.68         NaN                  NaN   15
# 57               144*            48.79         NaN                  NaN    5
#
#     50  0   4s  6s
# 8   19  6  258   2
# 15  14  1  107  11
# 57   6  3   51   0

# %%
df['Balls Faced']=df['Balls Faced'].fillna(0)

# %%
df['Batting Strike Rate']=df['Batting Strike Rate'].fillna(0)

# %%
#display changed made to 'Balls Faced'& 'Batting strike rate' by ED Weekes, CL Walcott, Hon. FS Jackson
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  Not Outs  Runs  \
# 8  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 8                207            58.61           0                  0.0   15
#
#    50  0   4s  6s
# 8  19  6  258   2

# %%
#drop duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#               Player       Span  Matches  Inns  Not Outs  Runs  \
# 10  WR Hammond (ENG)  1927-1947       85   140        16  7249
# 17    L Hutton (ENG)  1937-1955       79   138        15  6971
# 53     V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 10               336*            58.45       7491+                38.07   22
# 17                364            56.67       2844+                39.34   19
# 53               254*            49.15       15924                55.56   29
#
#     50   0   4s  6s
# 10  24   4  419  27
# 17  33   5  358   7
# 53  30  14  991  26

# %%
#cross-check duplicate records
df[df['Player'].isin(['WR Hammond (ENG)','L Hutton (ENG)','V Kohli (IND)'])]
# Out:
#               Player       Span  Matches  Inns  Not Outs  Runs  \
# 9   WR Hammond (ENG)  1927-1947       85   140        16  7249
# 10  WR Hammond (ENG)  1927-1947       85   140        16  7249
# 16    L Hutton (ENG)  1937-1955       79   138        15  6971
# 17    L Hutton (ENG)  1937-1955       79   138        15  6971
# 52     V Kohli (IND)  2011-2024      113   191        11  8848
# 53     V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 9                336*            58.45       7491+                38.07   22
# 10               336*            58.45       7491+                38.07   22
# 16                364            56.67       2844+                39.34   19
# 17                364            56.67       2844+                39.34   19
# 52               254*            49.15       15924                55.56   29
# ...

# %%
#drop duplicates
df=df.drop_duplicates()

# %%
df[df['Player'].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not Outs, Runs, Highest Inns Score, Batting Average, Balls Faced, Batting Strike Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 0                 334            99.94       9800+                58.60   29
# ...

# %%
#Split up 'Span' into Start and End date + Career length
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
#get start year from Span   ---ignore error here
df['Start Year']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_7208\1889837779.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start Year']=df['Span'].str.split(pat='-').str[0]

# %%
#get end year from Span  ---ignore error here
df['End Year']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_7208\2158580207.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End Year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest Inns Score  Batting Average Balls Faced  Batting Strike Rate  100  \
# 0                 334            99.94       9800+                58.60   29
# ...

# %%
#drop Span column
df=df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not Outs  Runs Highest Inns Score  \
# 0  DG Bradman (AUS)       52    80        10  6996                334
# 1    HC Brook (ENG)       12    20         1  1181                186
# 2    AC Voges (AUS)       20    31         7  1485               269*
# 3   RG Pollock (SA)       23    41         4  2256                274
# 4   GA Headley (WI)       22    40         4  2190               270*
#
#    Batting Average Balls Faced  Batting Strike Rate  100  50  0   4s  6s  \
# 0            99.94       9800+                58.60   29  13  7  626   6
# 1            62.15        1287                91.76    4   7  1  141  23
# 2            61.87        2667                55.68    5   4  2  186   5
# 3            60.97       1707+                54.48    7  11  1  246  11
# 4            60.83        416+                56.00   10   5  2  104   1
#
#   Start Year End Year
# 0       1928     1948
# 1       2022     2023
# 2       2015     2016
# ...

# %%
#1. split up the country from the player
df['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 60     [KD Walters , AUS)]
# 61    [GC Smith , ICC/SA)]
# 62    [WH Ponsford , AUS)]
# 63      [SJ McCabe , AUS)]
# 64     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
#df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
#df['Country']=df['Player'].str.split(pat=')').str[0]

# %%
df['Country'] = df['Player'].str.extract(r'\((.*?)\)')

# %%
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 60       AUS
# 61    ICC/SA
# 62       AUS
# 63       AUS
# 64       ENG
# Name: Country, Length: 62, dtype: object

# %%
#df['Player']=df['Player'].str.extract(r'^\s*([^(\d]+)')

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not Outs  Runs  Highest Inns Score  \
# 0  DG Bradman (AUS)       52    80        10  6996                 334
# 1    HC Brook (ENG)       12    20         1  1181                 186
# 2    AC Voges (AUS)       20    31         7  1485                 269
# 3   RG Pollock (SA)       23    41         4  2256                 274
# 4   GA Headley (WI)       22    40         4  2190                 270
#
#    Batting Average Balls Faced  Batting Strike Rate  100  50  0   4s  6s  \
# 0            99.94       9800+                58.60   29  13  7  626   6
# 1            62.15        1287                91.76    4   7  1  141  23
# 2            61.87        2667                55.68    5   4  2  186   5
# 3            60.97       1707+                54.48    7  11  1  246  11
# 4            60.83        416+                56.00   10   5  2  104   1
#
#   Start Year End Year Country
# 0       1928     1948     AUS
# 1       2022     2023     ENG
# ...

# %%
#check data types
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not Outs                 int64
# Runs                     int64
# Highest Inns Score      object
# Batting Average        float64
# Balls Faced             object
# Batting Strike Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start Year              object
# End Year                object
# Country                 object
# dtype: object

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not Outs                 int64
# Runs                     int64
# Highest Inns Score      object
# Batting Average        float64
# Balls Faced             object
# Batting Strike Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start Year              object
# End Year                object
# Country                 object
# dtype: object

# %%
df['Highest Inns Score'].str.split(pat= '*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest Inns Score, Length: 62, dtype: object

# %%
df['Highest Inns Score']=df['Highest Inns Score'].str.split(pat= '*').str[0]

# %%
df['Highest Inns Score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest Inns Score, Length: 62, dtype: object

# %%
df['Highest Inns Score'].astype('int')
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest Inns Score, Length: 62, dtype: int32

# %%
df['Highest Inns Score']=df['Highest Inns Score'].astype('int')

# %%
#change data types
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not Outs                 int64
# Runs                     int64
# Highest Inns Score       int32
# Batting Average        float64
# Balls Faced             object
# Batting Strike Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start Year              object
# End Year                object
# Country                 object
# dtype: object

# %%
#Similarly fix data types of Start and End Year -other way
df=df.astype({'Start Year':'int','End Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not Outs                 int64
# Runs                     int64
# Highest Inns Score       int32
# Batting Average        float64
# Balls Faced             object
# Batting Strike Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start Year               int32
# End Year                 int32
# Country                 object
# dtype: object

# %%
#similarly change data type of 'Balls Faced' into int
df['Balls Faced']=df['Balls Faced'].str.split(pat= '+').str[0]

# %%
df['Balls Faced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 60     8662
# 61    15525
# 62     3118
# 63     3217
# 64     2110
# Name: Balls Faced, Length: 62, dtype: object

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not Outs  Runs  Highest Inns Score  \
# 0  DG Bradman (AUS)       52    80        10  6996                 334
# 1    HC Brook (ENG)       12    20         1  1181                 186
# 2    AC Voges (AUS)       20    31         7  1485                 269
# 3   RG Pollock (SA)       23    41         4  2256                 274
# 4   GA Headley (WI)       22    40         4  2190                 270
#
#    Batting Average Balls Faced  Batting Strike Rate  100  50  0   4s  6s  \
# 0            99.94        9800                58.60   29  13  7  626   6
# 1            62.15        1287                91.76    4   7  1  141  23
# 2            61.87        2667                55.68    5   4  2  186   5
# 3            60.97        1707                54.48    7  11  1  246  11
# 4            60.83         416                56.00   10   5  2  104   1
#
#    Start Year  End Year Country
# 0        1928      1948     AUS
# 1        2022      2023     ENG
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not Outs                 int64
# Runs                     int64
# Highest Inns Score       int32
# Batting Average        float64
# Balls Faced             object
# Batting Strike Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start Year               int32
# End Year                 int32
# Country                 object
# dtype: object

# %%
df['Balls Faced']=df['Balls Faced'].astype('float')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not Outs                 int64
# Runs                     int64
# Highest Inns Score       int32
# Batting Average        float64
# Balls Faced            float64
# Batting Strike Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Start Year               int32
# End Year                 int32
# Country                 object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                       Player  Matches  Inns  Not Outs   Runs  \
# 0           DG Bradman (AUS)       52    80        10   6996
# 1             HC Brook (ENG)       12    20         1   1181
# 2             AC Voges (AUS)       20    31         7   1485
# 3            RG Pollock (SA)       23    41         4   2256
# 4            GA Headley (WI)       22    40         4   2190
# 5          H Sutcliffe (ENG)       54    84         9   4555
# 6            E Paynter (ENG)       20    31         5   1540
# 7        KF Barrington (ENG)       82   131        15   6806
# 8             ED Weekes (WI)       48    81         5   4455
# 9           WR Hammond (ENG)       85   140        16   7249
# 11           SPD Smith (AUS)      107   191        25   9634
# 12            GS Sobers (WI)       93   160        21   8032
# 13        KC Sangakkara (SL)      134   233        17  12400
# 14            JB Hobbs (ENG)       61   102         7   5410
# ...

# %%
#career length column (that is End Year - Start Year)
df['Career Length']=df['End Year']-df['Start Year']

# %%
df
# Out:
#                       Player  Matches  Inns  Not Outs   Runs  \
# 0           DG Bradman (AUS)       52    80        10   6996
# 1             HC Brook (ENG)       12    20         1   1181
# 2             AC Voges (AUS)       20    31         7   1485
# 3            RG Pollock (SA)       23    41         4   2256
# 4            GA Headley (WI)       22    40         4   2190
# 5          H Sutcliffe (ENG)       54    84         9   4555
# 6            E Paynter (ENG)       20    31         5   1540
# 7        KF Barrington (ENG)       82   131        15   6806
# 8             ED Weekes (WI)       48    81         5   4455
# 9           WR Hammond (ENG)       85   140        16   7249
# 11           SPD Smith (AUS)      107   191        25   9634
# 12            GS Sobers (WI)       93   160        21   8032
# 13        KC Sangakkara (SL)      134   233        17  12400
# 14            JB Hobbs (ENG)       61   102         7   5410
# ...

# %%
#cricketers in this df- what is the avg career length
df['Career Length'].mean().round(2)
# Out:
# 13.16

# %%
#Avg batting_batting_strike_rate for cricketers who have played over 10 years
df[df['Career Length']>10]['Batting Strike Rate'].mean().round(2)
# Out:
# 47.95

# %%
#find cricketers who played before 1960
df[df['Start Year']<1960]
# Out:
#                   Player  Matches  Inns  Not Outs  Runs  Highest Inns Score  \
# 0       DG Bradman (AUS)       52    80        10  6996                 334
# 4        GA Headley (WI)       22    40         4  2190                 270
# 5      H Sutcliffe (ENG)       54    84         9  4555                 194
# 6        E Paynter (ENG)       20    31         5  1540                 243
# 7    KF Barrington (ENG)       82   131        15  6806                 256
# 8         ED Weekes (WI)       48    81         5  4455                 207
# 9       WR Hammond (ENG)       85   140        16  7249                 336
# 12        GS Sobers (WI)       93   160        21  8032                 365
# 14        JB Hobbs (ENG)       61   102         7  5410                 211
# 15       CL Walcott (WI)       44    74         7  3798                 220
# 16        L Hutton (ENG)       79   138        15  6971                 364
# ...

# %%
#find number of cricketers who played before 1960
df[df['Start Year']<1960]['Player'].count()
# Out:
# 23

# %%
#max highest inns scored by country
df.groupby('Country')['Highest Inns Score'].max().to_frame('HighInnCountry').reset_index().sort_values('HighInnCountry',ascending=False)
# Out:
#     Country  HighInnCountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 6       IND             254
# 7        NZ             251
# 12      ZIM             232

# %%
#Hundreds,Fifties,ducks (0) AVG by country.
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.312500   8.500000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       17.000000  21.000000   5.500000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
